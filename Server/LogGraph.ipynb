# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import array

t1 = np.array([2000, 3000, 5000, 8000, 10000, 30000, 50000, 100000])

l1, = plt.plot(t1, np.log10(t1))

plt.xlabel('Income')
plt.ylabel('Value')
plt.title('Log result')

plt.show()
